# %% [markdown]
# # Sales Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
df = pd.read_csv('Sales_Data/Sales_April_2019.csv')
df.head(3)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001
# 1             NaN                                NaN
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215

# %% [markdown]
# ### Merge multiple CSV files into a single one

# %%
files = [file for file in os.listdir('Sales_Data/')]
for file in files:
    print(file)
# Out:
# Sales_July_2019.csv
# Sales_October_2019.csv
# Sales_December_2019.csv
# Sales_April_2019.csv
# Sales_January_2019.csv
# Sales_June_2019.csv
# Sales_February_2019.csv
# Sales_November_2019.csv
# Sales_September_2019.csv
# Sales_March_2019.csv
# Sales_August_2019.csv
# Sales_May_2019.csv

# %%
all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data,df])
    
all_months_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# ### Read in updated dataframe

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head(3)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
#
#        Order Date                 Purchase Address
# 0  07/26/19 16:51  389 South St, Atlanta, GA 30301
# 1  07/05/19 08:55    590 4th St, Seattle, WA 98101
# 2  07/29/19 12:41   861 Hill St, Atlanta, GA 30301

# %% [markdown]
# ### Clear Data

# %%
all_data['Month'] = all_data['Order Date'].str[:2]
all_data['Year'] = all_data['Order Date'].str[6:8]
all_data.head(3)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
#
#        Order Date                 Purchase Address Month Year
# 0  07/26/19 16:51  389 South St, Atlanta, GA 30301    07   19
# 1  07/05/19 08:55    590 4th St, Seattle, WA 98101    07   19
# 2  07/29/19 12:41   861 Hill St, Atlanta, GA 30301    07   19

# %% [markdown]
# ### Drop rows of NaN

# %%
all_data[all_data.isna().any(axis=1)].head(3)
# Out:
#     Order ID Product Quantity Ordered Price Each Order Date Purchase Address  \
# 199      NaN     NaN              NaN        NaN        NaN              NaN
# 315      NaN     NaN              NaN        NaN        NaN              NaN
# 599      NaN     NaN              NaN        NaN        NaN              NaN
#
#     Month Year
# 199   NaN  NaN
# 315   NaN  NaN
# 599   NaN  NaN

# %%
# Drop all columns with NaN values in every fields
all_data = all_data.dropna(how='all') #'any', to drop when appears any value

# %%
all_data.groupby('Month').count() # We have an indesirable 'Or' in Month column. Lest delete it.
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Month
# 01         9709     9709              9709        9709        9709
# 02        11975    11975             11975       11975       11975
# 03        15153    15153             15153       15153       15153
# 04        18279    18279             18279       18279       18279
# 05        16566    16566             16566       16566       16566
# 06        13554    13554             13554       13554       13554
# 07        14293    14293             14293       14293       14293
# 08        11961    11961             11961       11961       11961
# 09        11621    11621             11621       11621       11621
# 10        20282    20282             20282       20282       20282
# 11        17573    17573             17573       17573       17573
# 12        24984    24984             24984       24984       24984
# Or          355      355               355         355         355
#
#        Purchase Address   Year
# Month
# 01                 9709   9709
# 02                11975  11975
# 03                15153  15153
# 04                18279  18279
# 05                16566  16566
# 06                13554  13554
# 07                14293  14293
# 08                11961  11961
# 09                11621  11621
# 10                20282  20282
# 11                17573  17573
# 12                24984  24984
# Or                  355    355

# %%
temp_df = all_data[all_data['Order Date'].str[:2] == 'Or']  # Show all 'Or values'
temp_df
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 775     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1391    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1438    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1624    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1720    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 184506  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185634  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186178  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186449  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186720  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address Month Year
# 775     Purchase Address    Or   Da
# 1391    Purchase Address    Or   Da
# 1438    Purchase Address    Or   Da
# 1624    Purchase Address    Or   Da
# 1720    Purchase Address    Or   Da
# ...                  ...   ...  ...
# 184506  Purchase Address    Or   Da
# 185634  Purchase Address    Or   Da
# 186178  Purchase Address    Or   Da
# 186449  Purchase Address    Or   Da
# 186720  Purchase Address    Or   Da
#
# [355 rows x 8 columns]

# %%
all_data = all_data[all_data['Order Date'].str[:2] != 'Or'] # Delete every column with 'Or' value

# %%
all_data['Month'] = all_data['Month'].astype('int32') # Converting Month into an int32

# %%
all_data.head(3)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
#
#        Order Date                 Purchase Address  Month Year
# 0  07/26/19 16:51  389 South St, Atlanta, GA 30301      7   19
# 1  07/05/19 08:55    590 4th St, Seattle, WA 98101      7   19
# 2  07/29/19 12:41   861 Hill St, Atlanta, GA 30301      7   19

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
# Order ID            185950 non-null object
# Product             185950 non-null object
# Quantity Ordered    185950 non-null object
# Price Each          185950 non-null object
# Order Date          185950 non-null object
# Purchase Address    185950 non-null object
# Month               185950 non-null int32
# Year                185950 non-null object
# dtypes: int32(1), object(7)
# memory usage: 12.1+ MB

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered']) # Mmake int
all_data['Price Each'] = pd.to_numeric(all_data['Price Each']) # Mmake float
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
# Order ID            185950 non-null object
# Product             185950 non-null object
# Quantity Ordered    185950 non-null int64
# Price Each          185950 non-null float64
# Order Date          185950 non-null object
# Purchase Address    185950 non-null object
# Month               185950 non-null int32
# Year                185950 non-null object
# dtypes: float64(1), int32(1), int64(1), object(5)
# memory usage: 12.1+ MB

# %% [markdown]
# ### Add a Total Price Column

# %%
all_data['Total Price'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head(3)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
#
#        Order Date                 Purchase Address  Month Year  Total Price
# 0  07/26/19 16:51  389 South St, Atlanta, GA 30301      7   19       150.00
# 1  07/05/19 08:55    590 4th St, Seattle, WA 98101      7   19       300.00
# 2  07/29/19 12:41   861 Hill St, Atlanta, GA 30301      7   19         3.84

# %% [markdown]
# ### Q1: What was the best sales month?

# %%
sales = all_data.groupby('Month').sum()
sales
# Out:
#        Quantity Ordered    Price Each   Total Price
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
fig1, (ax1, ax2) = plt.subplots(1, 2, sharey=False, figsize=(16,4))

x = np.arange(1,13,1)

plt.style.use('ggplot')
fig1.suptitle('Sales per Month', size=30)

ax1.bar(x, sales['Total Price'], color='#1c4bba')

ax2.plot(x, sales['Total Price'], 'b--o')

plt.show()

# %%
plt.figure(figsize=(8, 4))
months = range(1, 13)
y = sales['Total Price']

plt.bar(months, y, color='#329c78')
# plt.plot(months, sales['Total Price'], 'r.-')
plt.title('Sales Per Month', fontsize=25)
plt.xticks(months)
plt.xlabel('Months')
plt.ylabel('Amount')

for i in months:
    plt.text(i, y[i], round(y[i], 2), ha="center", va="top", rotation="vertical", color="white")

plt.show()

# %% [markdown]
# ### Q2:  What city had the highest number of sales?

# %%
all_data.head(3)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
#
#        Order Date                 Purchase Address  Month Year  Total Price
# 0  07/26/19 16:51  389 South St, Atlanta, GA 30301      7   19       150.00
# 1  07/05/19 08:55    590 4th St, Seattle, WA 98101      7   19       300.00
# 2  07/29/19 12:41   861 Hill St, Atlanta, GA 30301      7   19         3.84

# %% [markdown]
# ### Add a City column

# %%
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: get_city(x) + '-' + get_state(x))

# all_data['City'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[1])
all_data.head(3)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
#
#        Order Date                 Purchase Address  Month Year  Total Price  \
# 0  07/26/19 16:51  389 South St, Atlanta, GA 30301      7   19       150.00
# 1  07/05/19 08:55    590 4th St, Seattle, WA 98101      7   19       300.00
# 2  07/29/19 12:41   861 Hill St, Atlanta, GA 30301      7   19         3.84
#
#           City
# 0   Atlanta-GA
# 1   Seattle-WA
# 2   Atlanta-GA

# %%
top_city = all_data.groupby('City').sum()
top_city
# Out:
#                    Quantity Ordered    Price Each   Month   Total Price
# City
#  Atlanta-GA                   16602  2.779908e+06  104794  2.795499e+06
#  Austin-TX                    11153  1.809874e+06   69829  1.819582e+06
#  Boston-MA                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas-TX                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles-CA               33289  5.421435e+06  208325  5.452571e+06
#  New York City-NY             27932  4.635371e+06  175741  4.664317e+06
#  Portland-ME                   2750  4.471893e+05   17144  4.497583e+05
#  Portland-OR                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco-CA             50239  8.211462e+06  315520  8.262204e+06
#  Seattle-WA                   16553  2.733296e+06  104941  2.747755e+06

# %%
fig, ax = plt.subplots(figsize=(10, 4))

x = all_data['City'].unique()
y = top_city['Total Price']

plt.barh(x, y.sort_values(ascending=False))
plt.title('Sales by City for Sales')
plt.xticks(rotation=-10)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
# palette = sns.color_palette("Blues", 10)
palette = sns.cubehelix_palette(10, start=2, rot=0, dark=0.1, light=.80, reverse=True)
x = all_data['City'].unique()
y = top_city['Total Price'].sort_values(ascending=False)

sns.barplot(data=top_city, x=x, y=y, palette=palette)
plt.title('Sales Per City')
plt.xticks(rotation=45)
plt.ylim(0, 10000000)

for i in range(len(x)):
    y[i] = y[i].astype("int32")
    plt.text(i, y[i], y[i], ha="center", va="bottom", rotation="vertical", color="darkgreen")

plt.show()

# %% [markdown]
# ### Q3: When is the best time to ads?

# %% [markdown]
# ### Convert "Order Date" in a DateTime object

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour # Creates the Hour field
all_data['Minute'] = all_data['Order Date'].dt.minute
all_data.head(1)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1       150.0
#
#            Order Date                 Purchase Address  Month Year  \
# 0 2019-07-26 16:51:00  389 South St, Atlanta, GA 30301      7   19
#
#    Total Price         City  Hour  Minute
# 0        150.0   Atlanta-GA    16      51

# %%
best_hour = all_data.groupby('Hour').sum()
best_hour.head(3)
# Out:
#       Quantity Ordered  Price Each  Month  Total Price  Minute
# Hour
# 0                 4428   709296.70  27554    713721.27  103596
# 1                 2619   458490.00  16657    460866.88   61807
# 2                 1398   233833.64   8507    234851.44   32508

# %%
fig, ax = plt.subplots(figsize=(12, 5))

hours = [hour for hour, df in all_data.groupby('Hour')]
y = all_data.groupby(['Hour']).count()

plt.plot(hours, y, color="Blue")
plt.title("Best Time To Advertisements", fontsize=25)
plt.xticks(hours)
plt.axhline(y=12000, xmin=0.1, xmax=0.9)

plt.show()

# %% [markdown]
# ### Q4: Which products are often sold together?

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]

#Join product names at the same order
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

#Delete duplicates
df = df[['Order ID', 'Grouped']].drop_duplicates()

df.head()
# Out:
# <ipython-input-64-2f3906fd583b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Order ID                                            Grouped
# 118   223028  Vareebadd Phone,USB-C Charging Cable,Wired Hea...
# 140   223048               Vareebadd Phone,USB-C Charging Cable
# 188   223095     Apple Airpods Headphones,AA Batteries (4-pack)
# 201   223106                   Wired Headphones,Vareebadd Phone
# 213   223117                  Google Phone,USB-C Charging Cable

# %%
#Reference: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import  Counter

count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))
    
for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### Q5: What product are mostly sold and why do you think it is sold the most?

# %%
all_data.head(3)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
#
#            Order Date                 Purchase Address  Month Year  \
# 0 2019-07-26 16:51:00  389 South St, Atlanta, GA 30301      7   19
# 1 2019-07-05 08:55:00    590 4th St, Seattle, WA 98101      7   19
# 2 2019-07-29 12:41:00   861 Hill St, Atlanta, GA 30301      7   19
#
#    Total Price         City  Hour  Minute
# 0       150.00   Atlanta-GA    16      51
# 1       300.00   Seattle-WA     8      55
# 2         3.84   Atlanta-GA    12      41

# %%
product_group = all_data.groupby('Product')
quantity_ordered = product_group['Quantity Ordered'].sum()

products = [product for product, df in product_group]

fig, ax = plt.subplots(figsize=(10,4))

plt.bar(products, quantity_ordered.sort_values(ascending=False))
plt.title("Most Sold Product", fontsize=25)
plt.xticks(rotation='vertical')
plt.ylabel("Quantity Ordered")

plt.show()

# %%
# product_group = all_data.groupby('Product')
# quantity_ordered = product_group['Quantity Ordered'].sum()
prices = all_data.groupby('Product')['Price Each'].mean()

# products = [product for product, df in product_group]

fig, ax1 = plt.subplots(figsize=(10,4))

ax2 = ax1.twinx()
ax1.bar(products, quantity_ordered.sort_values(ascending=False))
ax2.plot(products, prices, 'g.-')

fig.suptitle("Most Sold Product / Their price", fontsize=25)
ax1.set_xticklabels(products, rotation='vertical')
ax1.set_ylabel("Quantity Ordered")
ax2.set_ylabel("Price")

plt.show()
